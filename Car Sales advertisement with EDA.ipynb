# %% [markdown]
# # PROJECT : CAR SALES ADVERTISEMENT DATA TO ANALYSE THE CAR SALES IN UKRAINE

# %% [markdown]
# ---
# # **Table of Contents**
# ---
#
# 1. [**Introduction**](#Section1)<br>
# 2. [**Problem Statement**](#Section2)<br>
# 3. [**Installing & Importing Libraries**](#Section3)<br>
#   3.1 [**Installing Libraries**](#Section31)<br>
#   3.2 [**Upgrading Libraries**](#Section32)<br>
#   3.3 [**Importing Libraries**](#Section33)<br>
# 4. [**Data Acquisition & Description**](#Section4)<br>
# 5. [**Data Pre-Profiling**](#Section5)<br>
# 6. [**Data Pre-Processing**](#Section6)<br>
# 7. [**Data Post-Profiling**](#Section7)<br>
# 8. [**Exploratory Data Analysis**](#Section8)<br>
# 9. [**Summarization**](#Section9)</br>
#   9.1 [**Conclusion**](#Section91)</br>
#   9.2 [**Actionable Insights**](#Section91)</br>
#
# ---

# %% [markdown]
# # # **1. Introduction**
#
# The growing disposable income of the working people increased the market growth because this enables individuals to buy vehicles within a limited budget. As per Statistics disposable incomes in low-class households were augmented by 3% and 3.3% in the initial phase of 2021, respectively. In contrast, incomes in high-class households were reduced by 6.4% and then augmented by 3.9% over the same timeframe. The market growth for used cars witnessed substantial growth in the last few years because of expense competitiveness among new market players along with the inability of major share of customers to buy a new car.
#  Market Research analyses that the used car market was valued at USD 221,079.31 million in 2022 and is expected to reach the value of USD 371,418.43 million by 2030, at a CAGR of 6.70% during the forecast period. In addition to the market insights such as market value, growth rate, market segments, geographical coverage, market players, and market scenario, The market report generated by Market Research team includes in-depth expert analysis, import/export analysis, pricing analysis, production consumption analysis, and pestle analysis.
#
# This dataset is believed to contains data for more than 9500 cars sale in Ukraine The cars are all  used cars so it vbery important to access the possibility of their features such as mileage, model, make, engine capacity, fuel used etc etc  for their operation.
#
#  There is no information about the data collection method used for these cars which are already used ones.

# %% [markdown]
# # Data loading and the description of data
#
# The dataset contains 9576 observations in a total of 10 columns.
# The  table shows the  names of all the columns and their description.
#
#           Column Name: Description
#
#           Car: Manufacturer brand of the vehicle
#           Price: Seller’s price may be in in USD or EUROS
#           Body: Body type
#           Mileage: Could be in KM/hr
#           EngV: Volume of engine could be in cc
#           EngType: type of fuel whether it is petrol, diesel or gas or as NA
#           Registration: whether car registered or unregistered in Ukraine
#           Year: Year of manufactuire of that particular model of the car
#           Model: specific model name with respect to each brand
#           Drive: Drive type whether it is lrear, front or full

# %% [markdown]
# # **2. Problem Statement**
#
# Prices of new cars have skyrocketed, most people are incapable of buying a new one.
# Customers buying a new car always looks for value of money
# Due to increased price of new cars, used car sales are on a global increase
# Requirement for a used car price prediction system to effectively determine the worthiness of the car using a variety of features.
# Different models and systems may contribute on predicting power for a used car’s actual market value.
# It is important to know their actual market value while both buying and selling and also the effective and attractive features which help in the sales of the used cars in Ukraine
# Parameters that help drive sales are model, mileage, fuel type and drives

# %% [markdown]
# ---
# <a id = Section3></a>
# # **3. Installing & Importing Libraries**
# ---
#
# - This section is emphasised on installing and importing the necessary libraries that will be required.

# %% [markdown]
# ### **Installing Libraries**

# %%
# !pip install -q datascience                                         # Package that is required by pandas profiling
# !pip install -q pandas-profiling                                    # Library to generate basic statistics about data
# To install more libraries insert your code here..

# %% [markdown]
# ### **Upgrading Libraries**
#
# - **After upgrading** the libraries, you need to **restart the runtime** to make the libraries in sync.
#
# - Make sure not to execute the cell under Installing Libraries and Upgrading Libraries again after restarting the runtime.

# %%
# !pip install -q --upgrade pandas-profiling                          # Upgrading pandas profiling to the latest version

# %% [markdown]
# ### **Importing Libraries**
#
# - You can headstart with the basic libraries as imported inside the cell below.
#
# - If you want to import some additional libraries, feel free to do so.

# %%
import pandas as pd                                                 # Importing package pandas (For Panel Data Analysis)
                    

#--------------------------------------------------------------------------------------------------------------------------------
pd.set_option('display.max_columns', None)                          # Unfolding hidden features if the cardinality is high
pd.set_option('display.max_colwidth', None)                         # Unfolding the max feature width for better clearity
pd.set_option('display.max_rows', None)                             # Unfolding hidden data points if the cardinality is high
pd.set_option('mode.chained_assignment', None)                      # Removing restriction over chained assignments operations
pd.set_option('display.float_format', lambda x: '%.5f' % x)         # To suppress scientific notation over exponential values

import numpy as np                                                  # Importing package numpys (For Numerical Python)
#-------------------------------------------------------------------------------------------------------------------------------
import matplotlib.pyplot as plt                                     # Importing pyplot interface to use matplotlib
import seaborn as sns                                               # Importing seaborn library for interactive visualization
# %matplotlib inline
import plotly.graph_objs as go                                      # For interactive graphs
#--------------------------------------------------------------------------------------------------------------------------------
import warnings                                                     # Importing warning to disable runtime warnings
warnings.filterwarnings("ignore")                                   # Warnings will appear only once

# %% [markdown]
# ---
# <a name = Section4></a>
# # **4. Data Acquisition & Description**
# ---
#
# - This section is emphasised on the accquiring the data and obtain some descriptive information out of it.
#
# - You could either scrap the data and then continue, or use a direct source of link (generally preferred in most cases).
#
# - You will be working with a direct source of link to head start your work without worrying about anything.
#
# - Before going further you must have a good idea about the features of the data set:
#
# |Id|Feature|Description|
# |:--|:--|:--|
# |01| car           | Car brand name|
# |02| model         | Available car different Variants|
# |03| year          | purchasing Year|
# |04| body          | Body type-Hatchback, Sedan, Crossover etc|
# |05| mileage       | car Mileage|
# |06| engV          | Engine version|
# |07| engType       | Car Fuel type - Petrol, Diesel, gas etc|
# |08| drive         | Wheel Drive Front, back|
# |09| registration  | Check if the vechile is registered|
# |10| price         | Price of Car in $|

# %%
CARSALES = pd.read_csv(filepath_or_buffer = 'https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/car_sales.csv', encoding='cp1252')
print('CARSALES Shape:', CARSALES.shape)
# Out:
# CARSALES Shape: (9576, 10)

# %% [markdown]
# # **Data Description**

# %%
CARSALES = pd.read_csv(filepath_or_buffer ='https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/car_sales.csv', encoding='cp1252')
CARSALES.describe()
# Out:
#              price    mileage       engV       year
# count   9576.00000 9576.00000 9142.00000 9576.00000
# mean   15633.31732  138.86236    2.64634 2006.60599
# std    24106.52344   98.62975    5.92770    7.06792
# min        0.00000    0.00000    0.10000 1953.00000
# 25%     4999.00000   70.00000    1.60000 2004.00000
# 50%     9200.00000  128.00000    2.00000 2008.00000
# 75%    16700.00000  194.00000    2.50000 2012.00000
# max   547800.00000  999.00000   99.99000 2016.00000

# %% [markdown]
# # OBSERVATIONS
# We can see the description of only three continuous features - price, mileage, engV and year The price feature ranges from 0 to 547800 per car. The midspread (middle 50%) of the price ranges from 8149.75 unit to 18551.63 The mileage ranges from 0.00 to 9576. We will have to deal with the 0 mileage too The midspread (middle 50%) of the mileage ranges from 91.472 to 395.25 Looking at the maximum value of the mileage, year and engV we can see that it may be misinformation. 25% of the cars have price 4999 dollars or less 50% of the cars have average price of 9200 dollars or less 75% of the cars have average price of 16700 dollars or less The max price is way too high i.e., 547800 dollars could be an outlier The maximum value of engV could be an outlier as it is 99.9

# %%
CARSALES.columns                                                  # This will print the names of all columns.
# Out:
# Index(['car', 'price', 'body', 'mileage', 'engV', 'engType', 'registration',
#        'year', 'model', 'drive'],
#       dtype='object')

# %%
CARSALES.shape                                         # This will print the number of rows and comlumns of the Data Fra
# Out:
# (9576, 10)

# %%
CARSALES.dtypes
# Out:
# car              object
# price           float64
# body             object
# mileage           int64
# engV            float64
# engType          object
# registration     object
# year              int64
# model            object
# drive            object
# dtype: object

# %%
CARSALES.head()                                                   # This will tell us the First 5rows of the Data Frame
# Out:
#              car       price       body  mileage    engV engType registration  \
# 0           Ford 15500.00000  crossover       68 2.50000     Gas          yes
# 1  Mercedes-Benz 20500.00000      sedan      173 1.80000     Gas          yes
# 2  Mercedes-Benz 35000.00000      other      135 5.50000  Petrol          yes
# 3  Mercedes-Benz 17800.00000        van      162 1.80000  Diesel          yes
# 4  Mercedes-Benz 33000.00000      vagon       91     NaN   Other          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %%
CARSALES.tail()                                                   # This will tell us the last 5 rows of the Data Frame
# Out:
#                 car       price       body  mileage    engV engType  \
# 9571        Hyundai 14500.00000  crossover      140 2.00000     Gas
# 9572     Volkswagen  2200.00000      vagon      150 1.60000  Petrol
# 9573  Mercedes-Benz 18500.00000  crossover      180 3.50000  Petrol
# 9574          Lexus 16999.00000      sedan      150 3.50000     Gas
# 9575           Audi 22500.00000      other       71 3.60000  Petrol
#
#      registration  year      model  drive
# 9571          yes  2011     Tucson  front
# 9572          yes  1986  Passat B2  front
# 9573          yes  2008     ML 350   full
# 9574          yes  2008     ES 350  front
# 9575          yes  2007         Q7   full

# %% [markdown]
# # **Data Information**

# %%
CARSALES.info()                                            # This will tell us about the Index, Datatype and Memory information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car           9576 non-null   object
#  1   price         9576 non-null   float64
#  2   body          9576 non-null   object
#  3   mileage       9576 non-null   int64
#  4   engV          9142 non-null   float64
#  5   engType       9576 non-null   object
#  6   registration  9576 non-null   object
#  7   year          9576 non-null   int64
#  8   model         9576 non-null   object
#  9   drive         9065 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 748.2+ KB

# %% [markdown]
# # Observations
# There are total of 10 columns and 9576 rows(entries
# Mileage is given as integer, it can be float too
# Registration should be boolean instead of object
# There are some missing information/values in drive and in engV

# %% [markdown]
# "we need to check on the maximum car price, mileage and engV.
# Which car has a price ==0, and to handle for each car model"

# %%
CARSALES.describe(include='all')
# Out:
#                car        price   body    mileage       engV engType  \
# count         9576   9576.00000   9576 9576.00000 9142.00000    9576
# unique          87          NaN      6        NaN        NaN       4
# top     Volkswagen          NaN  sedan        NaN        NaN  Petrol
# freq           936          NaN   3646        NaN        NaN    4379
# mean           NaN  15633.31732    NaN  138.86236    2.64634     NaN
# std            NaN  24106.52344    NaN   98.62975    5.92770     NaN
# min            NaN      0.00000    NaN    0.00000    0.10000     NaN
# 25%            NaN   4999.00000    NaN   70.00000    1.60000     NaN
# 50%            NaN   9200.00000    NaN  128.00000    2.00000     NaN
# 75%            NaN  16700.00000    NaN  194.00000    2.50000     NaN
# max            NaN 547800.00000    NaN  999.00000   99.99000     NaN
#
#        registration       year    model  drive
# count          9576 9576.00000     9576   9065
# ...

# %%
CARSALES.isnull().sum()
# Out:
# car               0
# price             0
# body              0
# mileage           0
# engV            434
# engType           0
# registration      0
# year              0
# model             0
# drive           511
# dtype: int64

# %% [raw]
# there are two columns where we can see that the sum of null values are 434 for engV and 511 for drive. We will be analysing these thoroughly

# %%
total = CARSALES.isnull().sum().sort_values(ascending=False)
percent = (CARSALES.isnull().sum()/CARSALES.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
print(missing_data)
# Out:
#               Total  Percent
# drive           511  0.05336
# engV            434  0.04532
# car               0  0.00000
# price             0  0.00000
# body              0  0.00000
# mileage           0  0.00000
# engType           0  0.00000
# registration      0  0.00000
# year              0  0.00000
# model             0  0.00000

# %% [markdown]
# ---
# <a name = Section5></a>
# # **5. Data Pre-Profiling**
# ---
#
# - This section is emphasised on getting a report about the data.
#
# - You need to perform pandas profiling and get some observations out of it...

# %%
# # profile = ProfileReport(df = CARSALES)
# profile.to_file(output_file = 'Pre Profiling Report.html')
# print('Accomplished!')Insert your code here...

# %%
profile = pandas_profiling.ProfileReport(CARSALES)
profile.to_file(outputfile="CARSALES_data_before_preprocessing.html")

# %% [markdown]
# # Observations
# There are 10 features with 9576 observations in the dataset.
#
# The cells have missing values.
#
# There are missing values in drive column and engV
#
# Some data has Numeric values such as : price (Float),Mileage (integer), engV (Float), Year (integer)
#
# Some price has 0 values that cannot be true to be real
#
# We need to explore the numeric variable of price and  find out if any are NaN in it.
#
# Mileage also has some 0 values that are just not possible for used car put up for sales in real situation
#
# Null values have been found for drive and engV that will have to be addressed.
#
# drive: There are 511 missing values. We need to find the reason and evaluate
#
# engV: There are 434 missing values. We need to find the reason for this too and evaluate

# %% [markdown]
# ---
# <a name = Section6></a>
# # **6. Data Pre-Processing**
# ---
#
# - This section is emphasised on performing data manipulation over unstructured data for further processing and analysis.
#
# - To modify unstructured data to strucuted data you need to verify and manipulate the integrity of the data by:
#   - Handling missing data,
#
#   - Handling redundant data,
#
#   - Handling inconsistent data,
#
#   - Handling outliers,
#
#   - Handling typos

# %%
# n this section, we will perform the cleaning operations over the features using information from the previous section.

# %%
print("'Mileage'")                                                                
print("Minimum Mileage: ", CARSALES["mileage"].min())
print("Maximum Mileage: ", CARSALES["mileage"].max())
print("How many values are NaN?: ", pd.isnull(CARSALES['mileage']).sum())
print("How many values are 0? : ",CARSALES.price[CARSALES.mileage == 0].count())
# Out:
# 'Mileage'
# Minimum Mileage:  0
# Maximum Mileage:  999
# How many values are NaN?:  0
# How many values are 0? :  348

# %%
print("'price'")                                                                
print("Minimum price: ", CARSALES["price"].min())
print("Maximum price: ", CARSALES["price"].max())
print("How many values are NaN?: ", pd.isnull(CARSALES['price']).sum())
print("How many values are 0? : ", CARSALES.price[CARSALES.price == 0].count())
# Out:
# 'price'
# Minimum price:  0.0
# Maximum price:  547800.0
# How many values are NaN?:  0
# How many values are 0? :  267

# %%
print("'engV'")                                                                
print("How many values are NaN?: ", pd.isnull(CARSALES['engV']).sum())
# Out:
# 'engV'
# How many values are NaN?:  434

# %%
print("'drive'")                                                                
print("How many values are NaN?: ", pd.isnull(CARSALES['drive']).sum())
# Out:
# 'drive'
# How many values are NaN?:  511

# %% [markdown]
# # CALCULATING THE MISSING DATA

# %%
CARSALES['drive'] = CARSALES['drive'].fillna("UnSpecified")   #Will replace all the NaN values by'Unspecified'.
CARSALES.drive.unique()
# Out:
# array(['full', 'rear', 'front', 'UnSpecified'], dtype=object)

# %% [raw]
# All the NAN have been filled by 'Unspecified' in the CARSALES file under drive

# %%
#Mileage
mileage_avg = sum(CARSALES['mileage']) / len(CARSALES['mileage'])
CARSALES['mileage_level'] = ["high mileage" if i > mileage_avg else "low mileage" for i in CARSALES['mileage']]
CARSALES.loc[:10]
# Out:
#               car       price       body  mileage    engV engType  \
# 0            Ford 15500.00000  crossover       68 2.50000     Gas
# 1   Mercedes-Benz 20500.00000      sedan      173 1.80000     Gas
# 2   Mercedes-Benz 35000.00000      other      135 5.50000  Petrol
# 3   Mercedes-Benz 17800.00000        van      162 1.80000  Diesel
# 4   Mercedes-Benz 33000.00000      vagon       91     NaN   Other
# 5          Nissan 16600.00000  crossover       83 2.00000  Petrol
# 6           Honda  6500.00000      sedan      199 2.00000  Petrol
# 7         Renault 10500.00000      vagon      185 1.50000  Diesel
# 8   Mercedes-Benz 21500.00000      sedan      146 1.80000     Gas
# 9   Mercedes-Benz 22700.00000      sedan      125 2.20000  Diesel
# 10         Nissan 20447.15400  crossover        0 1.20000  Petrol
#
#    registration  year    model        drive mileage_level
# 0           yes  2010     Kuga         full   low mileage
# ...

# %% [markdown]
# ---
# <a name = Section7></a>
# # **7. Data Post-Profiling**
# ---
#
# - This section is emphasised on getting a report about the data after the data manipulation.
#
# - You may end up observing some new changes, so keep it under check and make right observations.

# %%
CARSALES = pd.read_csv("postprocessing_CARSALES.csv")                             # Importing the data as pd.read_csv
profile = pandas_profiling.ProfileReport(CARSALES)
profile.to_file(outputfile="CARSALES_postprocessing.html")

# %% [raw]
# The CARSALES dataset now doesnot contain any missing values.
# WE did assign a  new feature called Mileage_Level. So, the pandas profiling report which we have generated after preprocessing will give us more beneficial insights.
#
# In the Dataset info, Total Missing(%) = 0.0%
# Number of variables becomes 11 from 10

# %% [markdown]
# ---
# <a name = Section8></a>
# # **8. Exploratory Data Analysis**
# ---
#
# - This section is emphasised on asking the right questions and perform analysis using the data.
#
# - Note that there is no limit how deep you can go, but make sure not to get distracted from right track.

# %% [raw]
# Now we can identify the patterns in the data of used CARSALES in UKRAINE

# %% [markdown]
# # Trend of  car sales with respect to Year

# %%
CARSALES['year'].value_counts().head(20).plot.bar()
# Out:
# <AxesSubplot:>

# %% [raw]
# This bar graph show the variation of the price range with respect to year. The year 2008 has the highest number of car sold and 1996 has the lowest number of cars sold with respect to used cars.

# %%
CARSALES'drive'] = CARSALES['drive'].fillna("UnSpecified")
mileage_avg = sum(CARSALES['mileage']) / len(CARSALES['mileage'])
CARSALES['mileage_level'] = ["high mileage" if i > mileage_avg else "low mileage" for i in CARSALES['mileage']]

# %% [markdown]
# # To find out the price of registered vs unregistered cars

# %%
sns.boxplot(x ='registration', y ='price', hue='mileage_level', data=CARSALES)
# Out:
# <AxesSubplot:xlabel='registration', ylabel='price'>

# %%
The box plot gives a clear pictute that the registered cars are more priced and typically in the price range between 500000-2000000 dollars. 
There are some very few cars which are very highly priced among the registered acrs and possibly they are outliers in the data ]

# %% [markdown]
# # Engine type cars most widely sold

# %%
ct = pd.value_counts(CARSALES['engType'].values, sort=False)
labels = CARSALES['engType'].unique()
labels.sort()
sizes = ct
ct.sort_index(inplace=True)
colors = ['red', 'yellow', 'green', 'violet']
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()

# %% [raw]
# In the pie chart we observe that Petrol cars are the most widely sold Engine Types of all. It is ~46% of the total cars
# The second most preferred fuel is Diesel which is 31.5%
# Gas and Other fuels are not so commonly used in the cars.

# %% [markdown]
# # Trend of increase of  price of cars over the years

# %%
CARSALES.plot(kind = 'scatter', x='year', y='price', alpha=1.0, color= 'r')
plt.xlabel("year")
plt.ylabel("price")
plt.title("Trend of increase of car prices over the years") 
plt.show()

# %% [raw]
# The following observations were noticed and insights were made:
# Price of all cars  increased over the period of time starting from 1953 onwards till 2016.
# The proce of the cars have increased tremendously after 2010 and in more recent years.
# The average price of cars in recent times is 1 lakh dollars approximately.

# %% [markdown]
# # Analysis of Cars: Among all the fuel types cars which driving features are expensive

# %%
fig, ax = plt.subplots(figsize=(15,7))
colors = ["r", "g","y"]
sns.barplot(x="engType", y="price", hue= "drive", palette="husl",data=CARSALES)
ax.set_title("Average price of vehicles by fuel type and drive",fontdict= {'size':12})
ax.xaxis.set_label_text("Type Of Fuel",fontdict= {'size':14})
ax.yaxis.set_label_text("Average Price",fontdict= {'size':14})
ticks = plt.setp(ax.get_xticklabels(),rotation=90)
plt.show()

# %% [raw]
# The following were the Observation from the above chart:
# Full drive cars of all engine type cars are high priced compared to other fuel types
# The second is  the Rear drive cars in all fuel types which are higly priced.
# The third category is of Petrol and Diesel Front drive cars which are almost equally priced and has not much of a price difference

# %% [markdown]
# # Average price of car with respect to its fuel types

# %%
fig, ax = plt.subplots(figsize=(7,5))
sns.barplot(x="engType", y="price", palette="husl",data=CARSALES)
ax.set_title("Average price of vehicles by fuel typ",fontdict= {'size':12})
ax.xaxis.set_label_text("Type Of Fuel",fontdict= {'size':14})
ax.yaxis.set_label_text("Average Price",fontdict= {'size':14})
plt.show()

# %%
It is observerd from the above bar chart that Diesel vehicless are the most highly priced followed by petrol
Gas vehicles atre the lowest priced compared to all other types

# %% [markdown]
# #  Fuel type cars with the highest mileage

# %%
fig, ax = plt.subplots(figsize=(7,5))
sns.barplot(x="engType", y="mileage", palette="husl",data=CARSALES)
ax.set_title("Average price of vehicles by Mileage",fontdict= {'size':12})
ax.xaxis.set_label_text("Type Of Fuel",fontdict= {'size':14})
ax.yaxis.set_label_text("Average Mileage",fontdict= {'size':14})
plt.show()

# %%
It is observed from the above chart that Diesel and Gas cars provide with  highest mileage of approximately 160 Km/hr.
The second is the petrol card which as the highest mileage approximately 118Km/hr.

# %% [markdown]
# # Observation of correlation between price of car and year of manufacture with mileage

# %%
corr = CARSALES.loc[:, CARSALES.dtypes != 'object'].corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap=sns.diverging_palette(220, 10, as_cmap=True))
# Out:
# <AxesSubplot:>

# %%
From the above correlation matrix (heat map) it was observed that Price-Mileage and  Mileage-year are highly correlated with each other.

# %% [markdown]
# # Which driving features of car are more amongst the carsales?

# %%
CARSALES['drive'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
From the above chart it is evident that the front drive carts are more in numbers where as full drive cars are the least.

# %% [markdown]
# # Trend of cars with respect to mileage >400 m/hr

# %%
carsales_plot = CARSALES[(CARSALES['mileage']> 400)]
fig,ax = plt.subplots(figsize=(15,8))
sns.countplot(x='car',data=carsales_plot)
plt.xlabel("Car")
plt.ylabel("Count")
plt.title("Maximum Mileage level vs Cars Types", fontsize=18, fontweight = "bold")
ticks = plt.setp(ax.get_xticklabels(),rotation=90)

# %%
From the above chart it is very clear that the maximum number of Car Mercedez benz has the highest mileage followed by volkswagen and BMW

# %% [markdown]
# # Preference of fuel type of Mercedes-Benz cars

# %%
CARSALES.loc[CARSALES['car'] == 'Mercedes-Benz']
top_10_model = Ukraine['engType'].value_counts()[:].to_frame()
plt.figure(figsize=(10,5))
sns.barplot(top_10_model['engType'],top_10_model.index,palette="coolwarm")
plt.title('Preference of Mercedes-Benz car fuel types',fontsize=18,fontweight="bold")
plt.xlabel('')
plt.show()

# %%
The disel Merecedes cars are most preferred by people when compared to petrol cars of Mercedes Benz

# %% [markdown]
# ---
# <a name = Section9></a>
# # **9. Summarization**
# ---

# %% [raw]
# We have created EDA using various visualization tools such as Bar chart, Box plot, heat maps scatter plots etc to get the accurate picture of the used car sales according to year of production, price, fuel types, drives, engine capacity and mileage in Ukraine. Which types of cars give high mileage, what is their fuel type and the drive types. This study would help the consumers in making a decision on which types of cars to be prefereed while purchasing used cars in Ukraine

# %% [markdown]
# <a name = Section91></a>
# ### **9.1 Conclusion**
#
# - In this part you need to provide a conclusion about your overall analysis.
#
# - Write down some short points that you have observed so far.

# %% [raw]
# The year 2008 has the highest number of car sold and 1996 has the lowest number of cars sold with respect to used cars.The Car sales Survey helped us to know the most preferred car brand and features affecting it.
# Diesels cars provide high mileage and are highly priced whereas Gas cars provide equally high mileage but are priced low.
# It was observed that Diesel and Gas cars provide with  highest mileage of approximately 160 Km/hr.
# Petrol cars are the most widely sold Engine Types of all. It is ~46% of the total cars
# The second most preferred fuel is Diesel which is 31.5% of the total cars
# Gas and Other fuels are not so commonly used in the cars.As Diesel cars are highly priced, Petrol cars are more sold
# The second is the petrol card which as the highest mileage approximately 118Km/hr.
# Front drive cars which have low mileage are highly priced.
# It was observed that Price-Mileage and  Mileage-year are highly correlated with each other.
# It was also concluded from EDA that  Diesel cars are most preferred amongst the Merecedes Benz cars by the consumers

# %% [markdown]
# <a name = Section92></a>
# ### **9.2 Actionable Insights**
#
# - This is a very crucial part where you will present your actionable insights.
# - You need to give suggestions about what could be applied and what not.
# - Make sure that these suggestions are short and to the point, ultimately it's a catalyst to your business.
